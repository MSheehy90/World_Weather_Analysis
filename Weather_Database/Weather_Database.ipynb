# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []
# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module

for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
       
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 729

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url ="http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8f56fa6289fba714559ded60f2741fdc

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
            # Parse the JSON and retrieve data.
            city_weather = requests.get(city_url).json()
            # Parse out the needed data.
            city_lat = city_weather["coord"]["lat"]
            city_lng = city_weather["coord"]["lon"]
            city_max_temp = city_weather["main"]["temp_max"]
            city_humidity = city_weather["main"]["humidity"]
            city_clouds = city_weather["clouds"]["all"]
            city_wind = city_weather["wind"]["speed"]
            city_country = city_weather["sys"]["country"]
            city_description = city_weather['weather'][0]['description']
         
            # Append the city information into city_data list.
            city_data.append({"City": city.title(),
                              "Lat": city_lat,
                              "Lng": city_lng,
                              "Max Temp": city_max_temp,
                              "Humidity": city_humidity,
                              "Cloudiness": city_clouds,
                              "Wind Speed": city_wind,
                              "Country": city_country,
                              "Current Description": city_description})
                            
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | zhigansk
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | bredasdorp
# Processing Record 4 of Set 1 | sao filipe
# Processing Record 5 of Set 1 | albany
# Processing Record 6 of Set 1 | saint-philippe
# Processing Record 7 of Set 1 | aklavik
# Processing Record 8 of Set 1 | leningradskiy
# Processing Record 9 of Set 1 | kruisfontein
# Processing Record 10 of Set 1 | baft
# Processing Record 11 of Set 1 | mar del plata
# Processing Record 12 of Set 1 | upernavik
# Processing Record 13 of Set 1 | georgetown
# Processing Record 14 of Set 1 | barrow
# Processing Record 15 of Set 1 | san patricio
# Processing Record 16 of Set 1 | hithadhoo
# Processing Record 17 of Set 1 | muros
# Processing Record 18 of Set 1 | busselton
# Processing Record 19 of Set 1 | malinovskiy
# Processing Record 20 of Set 1 | ushuaia
# Processing Record 21 of Set 1 | lebu
# Processing Record 22 of Set 1 | kutum
# Processing Record 23 of Set 1 | jamestown
# Processing Record 24 of Set 1 | nikolskoye
# Processing Record 25 of Set 1 | avarua
# Processing Record 26 of Set 1 | alice town
# Processing Record 27 of Set 1 | kanigoro
# Processing Record 28 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 29 of Set 1 | gladstone
# Processing Record 30 of Set 1 | ponta delgada
# Processing Record 31 of Set 1 | kapaa
# Processing Record 32 of Set 1 | bluff
# Processing Record 33 of Set 1 | peoria
# Processing Record 34 of Set 1 | mahenge
# Processing Record 35 of Set 1 | nouadhibou
# Processing Record 36 of Set 1 | tukrah
# Processing Record 37 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 38 of Set 1 | srednekolymsk
# Processing Record 39 of Set 1 | taoudenni
# Processing Record 40 of Set 1 | mataura
# Processing Record 41 of Set 1 | new norfolk
# Processing Record 42 of Set 1 | nioro
# Processing Record 43 of Set 1 | komsomolskiy
# Processing Record 44 of Set 1 | hermanus
# Processing Record 45 of Set 1 | tura
# Processing Record 46 of Set 1 | victoria
# Processing Record 47 of Set 1 | cabo san lucas
# Processing Record 48 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 49 of Set 1 | nongpoh
# Processing Record 50 of Set 1 | kaputa
# Processing Record 1 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 2 of Set 2 | goksun
# Processing Record 3 of Set 2 | butaritari
# Processing Record 4 of Set 2 | vaini
# Processing Record 5 of Set 2 | codrington
# Processing Record 6 of Set 2 | dombarovskiy
# Processing Record 7 of Set 2 | margau
# Processing Record 8 of Set 2 | atuona
# Processing Record 9 of Set 2 | coihaique
# Processing Record 10 of Set 2 | ancud
# Processing Record 11 of Set 2 | puerto ayora
# Processing Record 12 of Set 2 | antalaha
# Processing Record 13 of Set 2 | kaitangata
# Processing Record 14 of Set 2 | viedma
# Processing Record 15 of Set 2 | yellowknife
# Processing Record 16 of Set 2 | ribeira grande
# Processing Record 17 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 18 of Set 2 | yar-sale
# Processing Record 19 of Set 2 | mafeteng
# Processing Record 20 of Set 2 | constitucion
# Processing Record 21 of Set 2 | morondava
# Processing Record 22 of Set 2 | severo-kurilsk
# Processing Record 23 of Set 2 | lashio
# Processing Record 24 of Set 2 | wasilla
# Processing Record 25 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 26 of Set 2 | nemuro
# Processing Record 27 of Set 2 | tigil
# Processing Record 28 of Set 2 | tabou
# Processing Record 29 of Set 2 | longyearbyen
# Processing Record 30 of Set 2 | gazojak
# Processing Record 31 of Set 2 | nerchinskiy zavod
# Processing Record 32 of Set 2 | carlsbad
# Processing Record 33 of Set 2 | bandarbeyla
# Processing Record 34 of Set 2 | belize
# Processing Record 35 of Set 2 | saint george
# Processing Record 36 of Set 2 | east stroudsburg
# Processing Record 37 of Set 2 | labuhan
# Processing Record 38 of Set 2 | tasiilaq
# Processing Record 39 of Set 2 | san ramon
# Processing Record 40 of Set 2 | seddon
# Processing Record 41 of Set 2 | chino valley
# Processing Record 42 of Set 2 | san javier
# Processing Record 43 of Set 2 | balad
# Processing Record 44 of Set 2 | conceicao da barra
# Processing Record 45 of Set 2 | fort nelson
# Processing Record 46 of Set 2 | port elizabeth
# Processing Record 47 of Set 2 | louisbourg
# City not found. Skipping...
# Processing Record 48 of Set 2 | komsomolskoye
# Processing Record 49 of Set 2 | kavieng
# Processing Record 50 of Set 2 | kavaratti
# Processing Record 1 of Set 3 | quatre cocos
# Processing Record 2 of Set 3 | arraial do cabo
# Processing Record 3 of Set 3 | vardo
# Processing Record 4 of Set 3 | mogadishu
# Processing Record 5 of Set 3 | ussuriysk
# Processing Record 6 of Set 3 | port alfred
# Processing Record 7 of Set 3 | barcelos
# Processing Record 8 of Set 3 | cajati
# Processing Record 9 of Set 3 | lucapa
# Processing Record 10 of Set 3 | grindavik
# Processing Record 11 of Set 3 | vila franca do campo
# Processing Record 12 of Set 3 | alyangula
# Processing Record 13 of Set 3 | sakaiminato
# Processing Record 14 of Set 3 | wamba
# Processing Record 15 of Set 3 | hasaki
# Processing Record 16 of Set 3 | akim swedru
# Processing Record 17 of Set 3 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 18 of Set 3 | bathsheba
# Processing Record 19 of Set 3 | beringovskiy
# Processing Record 20 of Set 3 | namibe
# Processing Record 21 of Set 3 | mochalishche
# Processing Record 22 of Set 3 | nong khae
# Processing Record 23 of Set 3 | svetlogorsk
# Processing Record 24 of Set 3 | narsaq
# Processing Record 25 of Set 3 | hobart
# Processing Record 26 of Set 3 | isangel
# Processing Record 27 of Set 3 | hilo
# Processing Record 28 of Set 3 | tuatapere
# Processing Record 29 of Set 3 | aketi
# Processing Record 30 of Set 3 | nevelsk
# Processing Record 31 of Set 3 | oktyabrskiy
# Processing Record 32 of Set 3 | tilichiki
# Processing Record 33 of Set 3 | chokurdakh
# Processing Record 34 of Set 3 | safaga
# Processing Record 35 of Set 3 | carnarvon
# Processing Record 36 of Set 3 | florence
# Processing Record 37 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 38 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 39 of Set 3 | tevaitoa
# Processing Record 40 of Set 3 | alugan
# Processing Record 41 of Set 3 | sioux lookout
# Processing Record 42 of Set 3 | ostrovnoy
# Processing Record 43 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 44 of Set 3 | makokou
# Processing Record 45 of Set 3 | grand gaube
# Processing Record 46 of Set 3 | salalah
# Processing Record 47 of Set 3 | kovdor
# Processing Record 48 of Set 3 | trzebiatow
# Processing Record 49 of Set 3 | liepaja
# Processing Record 50 of Set 3 | russkaya polyana
# Processing Record 1 of Set 4 | villa maria
# Processing Record 2 of Set 4 | tiksi
# Processing Record 3 of Set 4 | myitkyina
# Processing Record 4 of Set 4 | chabahar
# Processing Record 5 of Set 4 | westport
# Processing Record 6 of Set 4 | cayenne
# Processing Record 7 of Set 4 | xiaolingwei
# Processing Record 8 of Set 4 | biankouma
# Processing Record 9 of Set 4 | caluquembe
# Processing Record 10 of Set 4 | ponta do sol
# Processing Record 11 of Set 4 | bouna
# Processing Record 12 of Set 4 | tuktoyaktuk
# Processing Record 13 of Set 4 | nome
# Processing Record 14 of Set 4 | cape town
# Processing Record 15 of Set 4 | antigonish
# Processing Record 16 of Set 4 | tiarei
# Processing Record 17 of Set 4 | kushiro
# Processing Record 18 of Set 4 | kodiak
# Processing Record 19 of Set 4 | punta arenas
# Processing Record 20 of Set 4 | huarmey
# Processing Record 21 of Set 4 | souillac
# Processing Record 22 of Set 4 | stockelsdorf
# Processing Record 23 of Set 4 | camacha
# Processing Record 24 of Set 4 | samalaeulu
# City not found. Skipping...
# Processing Record 25 of Set 4 | wonthaggi
# Processing Record 26 of Set 4 | san carlos de bariloche
# Processing Record 27 of Set 4 | monrovia
# Processing Record 28 of Set 4 | liancheng
# Processing Record 29 of Set 4 | kizner
# Processing Record 30 of Set 4 | tidore
# City not found. Skipping...
# Processing Record 31 of Set 4 | katsuura
# Processing Record 32 of Set 4 | baykit
# Processing Record 33 of Set 4 | kavali
# Processing Record 34 of Set 4 | andenes
# Processing Record 35 of Set 4 | kamina
# Processing Record 36 of Set 4 | sabha
# Processing Record 37 of Set 4 | saskylakh
# Processing Record 38 of Set 4 | faanui
# Processing Record 39 of Set 4 | khatanga
# Processing Record 40 of Set 4 | meulaboh
# Processing Record 41 of Set 4 | melo
# Processing Record 42 of Set 4 | airai
# Processing Record 43 of Set 4 | naze
# Processing Record 44 of Set 4 | kenora
# Processing Record 45 of Set 4 | port lincoln
# Processing Record 46 of Set 4 | anderson
# Processing Record 47 of Set 4 | bethel
# Processing Record 48 of Set 4 | hirado
# Processing Record 49 of Set 4 | salinopolis
# Processing Record 50 of Set 4 | itoman
# Processing Record 1 of Set 5 | emba
# Processing Record 2 of Set 5 | sola
# Processing Record 3 of Set 5 | deputatskiy
# Processing Record 4 of Set 5 | ilhabela
# Processing Record 5 of Set 5 | stepnogorsk
# Processing Record 6 of Set 5 | laguna
# Processing Record 7 of Set 5 | yanam
# Processing Record 8 of Set 5 | thompson
# Processing Record 9 of Set 5 | paamiut
# Processing Record 10 of Set 5 | plato
# Processing Record 11 of Set 5 | norman wells
# Processing Record 12 of Set 5 | koundara
# Processing Record 13 of Set 5 | galiwinku
# City not found. Skipping...
# Processing Record 14 of Set 5 | coahuayana
# Processing Record 15 of Set 5 | bayir
# Processing Record 16 of Set 5 | diego de almagro
# Processing Record 17 of Set 5 | college
# Processing Record 18 of Set 5 | mbacke
# City not found. Skipping...
# Processing Record 19 of Set 5 | starotimoshkino
# Processing Record 20 of Set 5 | shelburne
# Processing Record 21 of Set 5 | banyo
# Processing Record 22 of Set 5 | areka
# Processing Record 23 of Set 5 | halifax
# Processing Record 24 of Set 5 | cidreira
# Processing Record 25 of Set 5 | saint-augustin
# Processing Record 26 of Set 5 | kargalinskaya
# Processing Record 27 of Set 5 | torbay
# Processing Record 28 of Set 5 | sao felix do xingu
# Processing Record 29 of Set 5 | sipe sipe
# Processing Record 30 of Set 5 | huntsville
# Processing Record 31 of Set 5 | geraldton
# Processing Record 32 of Set 5 | guerrero negro
# Processing Record 33 of Set 5 | provideniya
# Processing Record 34 of Set 5 | marapanim
# Processing Record 35 of Set 5 | batie
# Processing Record 36 of Set 5 | qaanaaq
# Processing Record 37 of Set 5 | moussoro
# Processing Record 38 of Set 5 | mount isa
# Processing Record 39 of Set 5 | abu dhabi
# Processing Record 40 of Set 5 | garowe
# Processing Record 41 of Set 5 | east london
# Processing Record 42 of Set 5 | haapu
# City not found. Skipping...
# Processing Record 43 of Set 5 | el alto
# Processing Record 44 of Set 5 | puerto escondido
# Processing Record 45 of Set 5 | olafsvik
# Processing Record 46 of Set 5 | amahai
# Processing Record 47 of Set 5 | juneau
# Processing Record 48 of Set 5 | astoria
# Processing Record 49 of Set 5 | novaya ladoga
# Processing Record 50 of Set 5 | wajima
# Processing Record 1 of Set 6 | hamilton
# Processing Record 2 of Set 6 | avera
# Processing Record 3 of Set 6 | dikson
# Processing Record 4 of Set 6 | shwebo
# Processing Record 5 of Set 6 | lavrentiya
# Processing Record 6 of Set 6 | atikokan
# Processing Record 7 of Set 6 | beloha
# Processing Record 8 of Set 6 | pinheiro machado
# Processing Record 9 of Set 6 | marystown
# Processing Record 10 of Set 6 | kodinsk
# Processing Record 11 of Set 6 | aykhal
# Processing Record 12 of Set 6 | amga
# Processing Record 13 of Set 6 | mae hong son
# Processing Record 14 of Set 6 | fortuna
# Processing Record 15 of Set 6 | bima
# Processing Record 16 of Set 6 | sayyan
# Processing Record 17 of Set 6 | ylivieska
# Processing Record 18 of Set 6 | mwinilunga
# Processing Record 19 of Set 6 | roald
# Processing Record 20 of Set 6 | goderich
# Processing Record 21 of Set 6 | taksimo
# Processing Record 22 of Set 6 | gizo
# Processing Record 23 of Set 6 | alihe
# Processing Record 24 of Set 6 | illapel
# Processing Record 25 of Set 6 | matara
# Processing Record 26 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 27 of Set 6 | castro
# Processing Record 28 of Set 6 | miri
# Processing Record 29 of Set 6 | chapais
# Processing Record 30 of Set 6 | itum-kale
# Processing Record 31 of Set 6 | port blair
# Processing Record 32 of Set 6 | florianopolis
# Processing Record 33 of Set 6 | phan rang
# City not found. Skipping...
# Processing Record 34 of Set 6 | chatsu
# City not found. Skipping...
# Processing Record 35 of Set 6 | shuangyang
# Processing Record 36 of Set 6 | san andres
# Processing Record 37 of Set 6 | mount gambier
# Processing Record 38 of Set 6 | aden
# Processing Record 39 of Set 6 | vao
# Processing Record 40 of Set 6 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 41 of Set 6 | nawa
# Processing Record 42 of Set 6 | liku
# Processing Record 43 of Set 6 | belousovka
# Processing Record 44 of Set 6 | berezovyy
# Processing Record 45 of Set 6 | port augusta
# Processing Record 46 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 47 of Set 6 | lalsot
# Processing Record 48 of Set 6 | pevek
# Processing Record 49 of Set 6 | labutta
# City not found. Skipping...
# Processing Record 50 of Set 6 | lata
# Processing Record 1 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 2 of Set 7 | antofagasta
# Processing Record 3 of Set 7 | homer
# Processing Record 4 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 5 of Set 7 | qaqortoq
# Processing Record 6 of Set 7 | tubuala
# Processing Record 7 of Set 7 | itacarambi
# Processing Record 8 of Set 7 | arlit
# Processing Record 9 of Set 7 | san juan
# Processing Record 10 of Set 7 | yining
# Processing Record 11 of Set 7 | kungurtug
# Processing Record 12 of Set 7 | skibbereen
# Processing Record 13 of Set 7 | san cristobal
# Processing Record 14 of Set 7 | barentsburg
# City not found. Skipping...
# Processing Record 15 of Set 7 | campbell river
# Processing Record 16 of Set 7 | contai
# Processing Record 17 of Set 7 | angoche
# Processing Record 18 of Set 7 | dhanwar
# Processing Record 19 of Set 7 | zemio
# Processing Record 20 of Set 7 | lasa
# Processing Record 21 of Set 7 | athabasca
# Processing Record 22 of Set 7 | slave lake
# Processing Record 23 of Set 7 | rawannawi
# City not found. Skipping...
# Processing Record 24 of Set 7 | cuamba
# Processing Record 25 of Set 7 | salym
# Processing Record 26 of Set 7 | karratha
# Processing Record 27 of Set 7 | ayan
# Processing Record 28 of Set 7 | sao joao da barra
# Processing Record 29 of Set 7 | margate
# Processing Record 30 of Set 7 | talara
# Processing Record 31 of Set 7 | payo
# Processing Record 32 of Set 7 | anloga
# Processing Record 33 of Set 7 | luganville
# Processing Record 34 of Set 7 | lazarev
# Processing Record 35 of Set 7 | jalu
# Processing Record 36 of Set 7 | egvekinot
# Processing Record 37 of Set 7 | pacific grove
# Processing Record 38 of Set 7 | rocha
# Processing Record 39 of Set 7 | jinka
# Processing Record 40 of Set 7 | sanchez
# Processing Record 41 of Set 7 | pangnirtung
# Processing Record 42 of Set 7 | griffith
# Processing Record 43 of Set 7 | kholodnyy
# Processing Record 44 of Set 7 | atar
# Processing Record 45 of Set 7 | sumenep
# Processing Record 46 of Set 7 | warmbad
# Processing Record 47 of Set 7 | celestun
# Processing Record 48 of Set 7 | galle
# Processing Record 49 of Set 7 | bengkulu
# Processing Record 50 of Set 7 | glenwood springs
# Processing Record 1 of Set 8 | taltal
# Processing Record 2 of Set 8 | zabol
# Processing Record 3 of Set 8 | la reforma
# Processing Record 4 of Set 8 | north bend
# Processing Record 5 of Set 8 | turki
# Processing Record 6 of Set 8 | clyde river
# Processing Record 7 of Set 8 | palmares do sul
# Processing Record 8 of Set 8 | pochutla
# Processing Record 9 of Set 8 | kahului
# Processing Record 10 of Set 8 | berlevag
# Processing Record 11 of Set 8 | alta floresta
# Processing Record 12 of Set 8 | batticaloa
# Processing Record 13 of Set 8 | tete
# Processing Record 14 of Set 8 | lafia
# Processing Record 15 of Set 8 | thinadhoo
# Processing Record 16 of Set 8 | panaba
# Processing Record 17 of Set 8 | asau
# Processing Record 18 of Set 8 | yumen
# Processing Record 19 of Set 8 | eldikan
# City not found. Skipping...
# Processing Record 20 of Set 8 | chusovoy
# Processing Record 21 of Set 8 | kawambwa
# Processing Record 22 of Set 8 | bubaque
# Processing Record 23 of Set 8 | powell river
# Processing Record 24 of Set 8 | aranos
# Processing Record 25 of Set 8 | luderitz
# Processing Record 26 of Set 8 | trat
# Processing Record 27 of Set 8 | arrifes
# Processing Record 28 of Set 8 | lingao
# Processing Record 29 of Set 8 | kushima
# Processing Record 30 of Set 8 | hovd
# Processing Record 31 of Set 8 | harper
# Processing Record 32 of Set 8 | itamaraca
# Processing Record 33 of Set 8 | te anau
# Processing Record 34 of Set 8 | toliary
# City not found. Skipping...
# Processing Record 35 of Set 8 | cherskiy
# Processing Record 36 of Set 8 | khorramshahr
# Processing Record 37 of Set 8 | talnakh
# Processing Record 38 of Set 8 | san miguel
# Processing Record 39 of Set 8 | rio muerto
# Processing Record 40 of Set 8 | ilulissat
# Processing Record 41 of Set 8 | merauke
# Processing Record 42 of Set 8 | hay river
# Processing Record 43 of Set 8 | linjiang
# Processing Record 44 of Set 8 | bell ville
# Processing Record 45 of Set 8 | maniitsoq
# Processing Record 46 of Set 8 | puerto narino
# Processing Record 47 of Set 8 | norden
# Processing Record 48 of Set 8 | derzhavinsk
# Processing Record 49 of Set 8 | macau
# Processing Record 50 of Set 8 | husavik
# Processing Record 1 of Set 9 | gornopravdinsk
# Processing Record 2 of Set 9 | shache
# Processing Record 3 of Set 9 | villa rica
# Processing Record 4 of Set 9 | green river
# Processing Record 5 of Set 9 | galesong
# Processing Record 6 of Set 9 | bambous virieux
# Processing Record 7 of Set 9 | hofn
# Processing Record 8 of Set 9 | kieta
# Processing Record 9 of Set 9 | kloulklubed
# Processing Record 10 of Set 9 | walvis bay
# Processing Record 11 of Set 9 | klaksvik
# Processing Record 12 of Set 9 | katherine
# Processing Record 13 of Set 9 | falealupo
# City not found. Skipping...
# Processing Record 14 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 15 of Set 9 | callaway
# Processing Record 16 of Set 9 | saint-pierre
# Processing Record 17 of Set 9 | tignere
# Processing Record 18 of Set 9 | bend
# Processing Record 19 of Set 9 | kefamenanu
# Processing Record 20 of Set 9 | kretinga
# Processing Record 21 of Set 9 | noshiro
# Processing Record 22 of Set 9 | manta
# Processing Record 23 of Set 9 | la ronge
# Processing Record 24 of Set 9 | veere
# Processing Record 25 of Set 9 | nazas
# Processing Record 26 of Set 9 | novokruchininskiy
# Processing Record 27 of Set 9 | gannan
# Processing Record 28 of Set 9 | lhokseumawe
# Processing Record 29 of Set 9 | hambantota
# Processing Record 30 of Set 9 | eyl
# Processing Record 31 of Set 9 | roma
# Processing Record 32 of Set 9 | santiago de cao
# Processing Record 33 of Set 9 | mullaitivu
# City not found. Skipping...
# Processing Record 34 of Set 9 | kununurra
# Processing Record 35 of Set 9 | sumter
# Processing Record 36 of Set 9 | ambulu
# Processing Record 37 of Set 9 | rioja
# Processing Record 38 of Set 9 | kedrovyy
# Processing Record 39 of Set 9 | azpeitia
# Processing Record 40 of Set 9 | chumikan
# Processing Record 41 of Set 9 | yirol
# City not found. Skipping...
# Processing Record 42 of Set 9 | odweyne
# Processing Record 43 of Set 9 | palmerston north
# Processing Record 44 of Set 9 | yuxia
# Processing Record 45 of Set 9 | khandagayty
# Processing Record 46 of Set 9 | marathon
# Processing Record 47 of Set 9 | ixtapa
# Processing Record 48 of Set 9 | grafton
# Processing Record 49 of Set 9 | ruteng
# Processing Record 50 of Set 9 | katangli
# Processing Record 1 of Set 10 | tsihombe
# City not found. Skipping...
# Processing Record 2 of Set 10 | walla walla
# Processing Record 3 of Set 10 | polunochnoye
# Processing Record 4 of Set 10 | lompoc
# Processing Record 5 of Set 10 | pierre
# Processing Record 6 of Set 10 | xichang
# Processing Record 7 of Set 10 | lorengau
# Processing Record 8 of Set 10 | palu
# Processing Record 9 of Set 10 | dolbeau
# City not found. Skipping...
# Processing Record 10 of Set 10 | mokrous
# Processing Record 11 of Set 10 | winnemucca
# Processing Record 12 of Set 10 | erenhot
# Processing Record 13 of Set 10 | aginskoye
# Processing Record 14 of Set 10 | price
# Processing Record 15 of Set 10 | port hueneme
# Processing Record 16 of Set 10 | mezen
# Processing Record 17 of Set 10 | okhotsk
# Processing Record 18 of Set 10 | russell
# Processing Record 19 of Set 10 | mahebourg
# Processing Record 20 of Set 10 | xiongzhou
# Processing Record 21 of Set 10 | dhidhdhoo
# Processing Record 22 of Set 10 | luau
# Processing Record 23 of Set 10 | benguela
# Processing Record 24 of Set 10 | iracoubo
# Processing Record 25 of Set 10 | kikwit
# Processing Record 26 of Set 10 | mildura
# Processing Record 27 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 28 of Set 10 | abha
# Processing Record 29 of Set 10 | chuy
# Processing Record 30 of Set 10 | talah
# City not found. Skipping...
# Processing Record 31 of Set 10 | barra patuca
# Processing Record 32 of Set 10 | skalistyy
# City not found. Skipping...
# Processing Record 33 of Set 10 | sisimiut
# Processing Record 34 of Set 10 | puerto baquerizo moreno
# Processing Record 35 of Set 10 | rungata
# City not found. Skipping...
# Processing Record 36 of Set 10 | tocopilla
# Processing Record 37 of Set 10 | miandrivazo
# Processing Record 38 of Set 10 | dunedin
# Processing Record 39 of Set 10 | lakatoro
# Processing Record 40 of Set 10 | leeuwarden
# Processing Record 41 of Set 10 | port keats
# Processing Record 42 of Set 10 | erdenet
# Processing Record 43 of Set 10 | dingle
# Processing Record 44 of Set 10 | kholmy
# Processing Record 45 of Set 10 | ambovombe
# Processing Record 46 of Set 10 | ensley
# Processing Record 47 of Set 10 | paoua
# Processing Record 48 of Set 10 | saldanha
# Processing Record 49 of Set 10 | escanaba
# Processing Record 50 of Set 10 | zhangye
# Processing Record 1 of Set 11 | sanok
# Processing Record 2 of Set 11 | radenci
# Processing Record 3 of Set 11 | buraydah
# Processing Record 4 of Set 11 | vila velha
# Processing Record 5 of Set 11 | dingzhou
# Processing Record 6 of Set 11 | acarau
# Processing Record 7 of Set 11 | nara
# Processing Record 8 of Set 11 | naugarzan
# City not found. Skipping...
# Processing Record 9 of Set 11 | fairbanks
# Processing Record 10 of Set 11 | burica
# City not found. Skipping...
# Processing Record 11 of Set 11 | zhangjiakou
# Processing Record 12 of Set 11 | lugovoy
# Processing Record 13 of Set 11 | catalina
# Processing Record 14 of Set 11 | sobolevo
# Processing Record 15 of Set 11 | lesogorsk
# Processing Record 16 of Set 11 | shakawe
# Processing Record 17 of Set 11 | shimoda
# Processing Record 18 of Set 11 | broken hill
# Processing Record 19 of Set 11 | kendari
# Processing Record 20 of Set 11 | moss vale
# Processing Record 21 of Set 11 | ormara
# Processing Record 22 of Set 11 | touros
# Processing Record 23 of Set 11 | ermelo
# Processing Record 24 of Set 11 | caravelas
# Processing Record 25 of Set 11 | santa vitoria do palmar
# Processing Record 26 of Set 11 | shenjiamen
# Processing Record 27 of Set 11 | gorin
# Processing Record 28 of Set 11 | laizhou
# Processing Record 29 of Set 11 | akividu
# Processing Record 30 of Set 11 | porto novo
# Processing Record 31 of Set 11 | sentyabrskiy
# City not found. Skipping...
# Processing Record 32 of Set 11 | harnosand
# Processing Record 33 of Set 11 | kattivakkam
# Processing Record 34 of Set 11 | wuzhou
# Processing Record 35 of Set 11 | rio gallegos
# Processing Record 36 of Set 11 | kilindoni
# Processing Record 37 of Set 11 | goundam
# Processing Record 38 of Set 11 | ust-koksa
# Processing Record 39 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 40 of Set 11 | carauari
# Processing Record 41 of Set 11 | mestia
# Processing Record 42 of Set 11 | sarkand
# Processing Record 43 of Set 11 | kuche
# City not found. Skipping...
# Processing Record 44 of Set 11 | zaysan
# Processing Record 45 of Set 11 | cooma
# Processing Record 46 of Set 11 | bonaventure
# Processing Record 47 of Set 11 | bargal
# City not found. Skipping...
# Processing Record 48 of Set 11 | mirik
# Processing Record 49 of Set 11 | jutai
# Processing Record 50 of Set 11 | vondrozo
# Processing Record 1 of Set 12 | nautla
# Processing Record 2 of Set 12 | idaho falls
# Processing Record 3 of Set 12 | kastamonu
# Processing Record 4 of Set 12 | ostersund
# Processing Record 5 of Set 12 | the valley
# Processing Record 6 of Set 12 | dubbo
# Processing Record 7 of Set 12 | formoso do araguaia
# City not found. Skipping...
# Processing Record 8 of Set 12 | la serena
# Processing Record 9 of Set 12 | san quintin
# Processing Record 10 of Set 12 | najran
# Processing Record 11 of Set 12 | pimentel
# Processing Record 12 of Set 12 | hinton
# Processing Record 13 of Set 12 | pedernales
# Processing Record 14 of Set 12 | boa vista
# Processing Record 15 of Set 12 | bansgaon
# Processing Record 16 of Set 12 | yulara
# Processing Record 17 of Set 12 | nanortalik
# Processing Record 18 of Set 12 | bassila
# Processing Record 19 of Set 12 | soc trang
# Processing Record 20 of Set 12 | tayoltita
# Processing Record 21 of Set 12 | dondo
# Processing Record 22 of Set 12 | arkhangelsk
# Processing Record 23 of Set 12 | guhagar
# Processing Record 24 of Set 12 | uwayl
# City not found. Skipping...
# Processing Record 25 of Set 12 | shingu
# Processing Record 26 of Set 12 | gejiu
# Processing Record 27 of Set 12 | pilar
# Processing Record 28 of Set 12 | sojat
# Processing Record 29 of Set 12 | dwarka
# Processing Record 30 of Set 12 | grand forks
# Processing Record 31 of Set 12 | belmonte
# Processing Record 32 of Set 12 | shiraz
# Processing Record 33 of Set 12 | xocali
# Processing Record 34 of Set 12 | innisfail
# Processing Record 35 of Set 12 | do rud
# City not found. Skipping...
# Processing Record 36 of Set 12 | bokspits
# City not found. Skipping...
# Processing Record 37 of Set 12 | sandavagur
# City not found. Skipping...
# Processing Record 38 of Set 12 | okato
# Processing Record 39 of Set 12 | alice springs
# Processing Record 40 of Set 12 | rabo de peixe
# Processing Record 41 of Set 12 | wabana
# Processing Record 42 of Set 12 | nebug
# Processing Record 43 of Set 12 | tacadang
# Processing Record 44 of Set 12 | yilan
# Processing Record 45 of Set 12 | hirara
# Processing Record 46 of Set 12 | hualmay
# Processing Record 47 of Set 12 | denham springs
# Processing Record 48 of Set 12 | ust-kuyga
# Processing Record 49 of Set 12 | howard springs
# Processing Record 50 of Set 12 | malinovoye ozero
# Processing Record 1 of Set 13 | vestmannaeyjar
# Processing Record 2 of Set 13 | hobyo
# Processing Record 3 of Set 13 | wanaka
# Processing Record 4 of Set 13 | bur gabo
# City not found. Skipping...
# Processing Record 5 of Set 13 | korla
# Processing Record 6 of Set 13 | kuala terengganu
# Processing Record 7 of Set 13 | campoverde
# Processing Record 8 of Set 13 | saint-georges
# Processing Record 9 of Set 13 | gobabis
# Processing Record 10 of Set 13 | carballo
# Processing Record 11 of Set 13 | khandyga
# Processing Record 12 of Set 13 | petropavlovsk-kamchatskiy
# Processing Record 13 of Set 13 | yerbogachen
# Processing Record 14 of Set 13 | necochea
# Processing Record 15 of Set 13 | champerico
# Processing Record 16 of Set 13 | makakilo city
# Processing Record 17 of Set 13 | padang
# Processing Record 18 of Set 13 | kang
# Processing Record 19 of Set 13 | santona
# Processing Record 20 of Set 13 | burgstadt
# Processing Record 21 of Set 13 | zhicheng
# Processing Record 22 of Set 13 | kalmunai
# Processing Record 23 of Set 13 | atakpame
# Processing Record 24 of Set 13 | samarai
# Processing Record 25 of Set 13 | qinzhou
# Processing Record 26 of Set 13 | chumphon
# Processing Record 27 of Set 13 | presidencia roque saenz pena
# Processing Record 28 of Set 13 | acapulco
# Processing Record 29 of Set 13 | rapid valley
# Processing Record 30 of Set 13 | kuloy
# Processing Record 31 of Set 13 | lagoa
# Processing Record 32 of Set 13 | sitka
# Processing Record 33 of Set 13 | codajas
# Processing Record 34 of Set 13 | mayo
# Processing Record 35 of Set 13 | liberal
# Processing Record 36 of Set 13 | zhezkazgan
# Processing Record 37 of Set 13 | chara
# Processing Record 38 of Set 13 | daxian
# City not found. Skipping...
# Processing Record 39 of Set 13 | vostok
# Processing Record 40 of Set 13 | haibowan
# City not found. Skipping...
# Processing Record 41 of Set 13 | coquimbo
# Processing Record 42 of Set 13 | koutiala
# Processing Record 43 of Set 13 | slidell
# Processing Record 44 of Set 13 | rudnichnyy
# Processing Record 45 of Set 13 | pangkalanbuun
# Processing Record 46 of Set 13 | gudari
# Processing Record 47 of Set 13 | pasighat
# Processing Record 48 of Set 13 | dalnerechensk
# Processing Record 49 of Set 13 | tonekabon
# Processing Record 50 of Set 13 | libourne
# Processing Record 1 of Set 14 | chapleau
# Processing Record 2 of Set 14 | kokopo
# Processing Record 3 of Set 14 | north platte
# Processing Record 4 of Set 14 | ondorhaan
# City not found. Skipping...
# Processing Record 5 of Set 14 | namatanai
# Processing Record 6 of Set 14 | eisenach
# Processing Record 7 of Set 14 | tamandare
# Processing Record 8 of Set 14 | velingara
# Processing Record 9 of Set 14 | balykshi
# Processing Record 10 of Set 14 | tazmalt
# Processing Record 11 of Set 14 | portland
# Processing Record 12 of Set 14 | linxia
# Processing Record 13 of Set 14 | buala
# Processing Record 14 of Set 14 | mocuba
# Processing Record 15 of Set 14 | ketchikan
# Processing Record 16 of Set 14 | bjornevatn
# Processing Record 17 of Set 14 | dongsheng
# Processing Record 18 of Set 14 | salta
# Processing Record 19 of Set 14 | iqaluit
# Processing Record 20 of Set 14 | belaya kholunitsa
# Processing Record 21 of Set 14 | waterloo
# Processing Record 22 of Set 14 | ippy
# Processing Record 23 of Set 14 | wanning
# Processing Record 24 of Set 14 | simand
# Processing Record 25 of Set 14 | wapakoneta
# Processing Record 26 of Set 14 | tudela
# Processing Record 27 of Set 14 | olinda
# Processing Record 28 of Set 14 | reyes
# Processing Record 29 of Set 14 | dezful
# Processing Record 30 of Set 14 | kiunga
# Processing Record 31 of Set 14 | zaraza
# Processing Record 32 of Set 14 | dumka
# Processing Record 33 of Set 14 | nishihara
# Processing Record 34 of Set 14 | pedro ii
# Processing Record 35 of Set 14 | sur
# Processing Record 36 of Set 14 | bosaso
# Processing Record 37 of Set 14 | providencia
# Processing Record 38 of Set 14 | brae
# Processing Record 39 of Set 14 | mandalgovi
# Processing Record 40 of Set 14 | port hardy
# Processing Record 41 of Set 14 | kosh-agach
# Processing Record 42 of Set 14 | san rafael
# Processing Record 43 of Set 14 | isla vista
# Processing Record 44 of Set 14 | ekibastuz
# Processing Record 45 of Set 14 | talladega
# Processing Record 46 of Set 14 | bambanglipuro
# Processing Record 47 of Set 14 | ati
# Processing Record 48 of Set 14 | biak
# Processing Record 49 of Set 14 | kemin
# Processing Record 50 of Set 14 | manjacaze
# Processing Record 1 of Set 15 | half moon bay
# Processing Record 2 of Set 15 | peace river
# Processing Record 3 of Set 15 | ganzhou
# Processing Record 4 of Set 15 | iralaya
# Processing Record 5 of Set 15 | show low
# Processing Record 6 of Set 15 | dreznica
# Processing Record 7 of Set 15 | sharjah
# Processing Record 8 of Set 15 | ust-nera
# Processing Record 9 of Set 15 | qui nhon
# Processing Record 10 of Set 15 | kenai
# Processing Record 11 of Set 15 | almaznyy
# Processing Record 12 of Set 15 | hervey bay
# Processing Record 13 of Set 15 | verkhnevilyuysk
# Processing Record 14 of Set 15 | zhuhai
# Processing Record 15 of Set 15 | kamenka
# Processing Record 16 of Set 15 | ulladulla
# Processing Record 17 of Set 15 | lichuan
# Processing Record 18 of Set 15 | huilong
# Processing Record 19 of Set 15 | ruatoria
# City not found. Skipping...
# Processing Record 20 of Set 15 | esperance
# Processing Record 21 of Set 15 | berga
# Processing Record 22 of Set 15 | pacatuba
# Processing Record 23 of Set 15 | barinas
# Processing Record 24 of Set 15 | changping
# Processing Record 25 of Set 15 | isilkul
# Processing Record 26 of Set 15 | urubicha
# Processing Record 27 of Set 15 | mbinga
# Processing Record 28 of Set 15 | carbonia
# Processing Record 29 of Set 15 | manzhouli
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 675

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Zhigansk  66.7697  123.3711     -7.67        97         100
# 1         Rikitea -23.1203 -134.9692     70.20        89         100
# 2      Bredasdorp -34.5322   20.0403     55.26        74         100
# 3      Sao Filipe  14.8961  -24.4956     78.55        75          80
# 4          Albany  42.6001  -73.9662     34.57        68          63
# 5  Saint-Philippe -21.3585   55.7679     69.39        69          28
# 6         Aklavik  68.2191 -135.0107     10.92        80          49
# 7   Leningradskiy  69.3833  178.4167      6.71        95         100
# 8    Kruisfontein -34.0033   24.7314     60.89        72         100
# 9            Baft  29.2340   56.6057     48.78        57          95
#
#    Wind Speed Country   Current Description
# 0       11.12      RU       overcast clouds
# 1        8.59      PF  heavy intensity rain
# 2        2.66      ZA       overcast clouds
# 3        3.74      CV         broken clouds
# 4        7.29      US         broken clouds
# 5        5.28      RE      scattered clouds
# 6        6.71      CA      scattered clouds
# 7       15.48      RU            light snow
# 8        1.32      ZA       overcast clouds
# 9        2.42      IR       overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed", "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]
# Display sample data
city_data_df.head()
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Zhigansk      RU  66.7697  123.3711     -7.67        97         100
# 1     Rikitea      PF -23.1203 -134.9692     70.20        89         100
# 2  Bredasdorp      ZA -34.5322   20.0403     55.26        74         100
# 3  Sao Filipe      CV  14.8961  -24.4956     78.55        75          80
# 4      Albany      US  42.6001  -73.9662     34.57        68          63
#
#    Wind Speed   Current Description
# 0       11.12       overcast clouds
# 1        8.59  heavy intensity rain
# 2        2.66       overcast clouds
# 3        3.74         broken clouds
# 4        7.29         broken clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="Citi_ID")
