# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []
# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module

for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
       
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 739

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url ="http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8f56fa6289fba714559ded60f2741fdc

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
            # Parse the JSON and retrieve data.
            city_weather = requests.get(city_url).json()
            # Parse out the needed data.
            city_lat = city_weather["coord"]["lat"]
            city_lng = city_weather["coord"]["lon"]
            city_max_temp = city_weather["main"]["temp_max"]
            city_humidity = city_weather["main"]["humidity"]
            city_clouds = city_weather["clouds"]["all"]
            city_wind = city_weather["wind"]["speed"]
            city_country = city_weather["sys"]["country"]
            # Convert the date to ISO standard.
            city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
            # Append the city information into city_data list.
            city_data.append({"City": city.title(),
                              "Lat": city_lat,
                              "Lng": city_lng,
                              "Max Temp": city_max_temp,
                              "Humidity": city_humidity,
                              "Cloudiness": city_clouds,
                              "Wind Speed": city_wind,
                              "Country": city_country})
                            
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | coahuayana
# Processing Record 2 of Set 1 | dikson
# Processing Record 3 of Set 1 | sedelnikovo
# City not found. Skipping...
# Processing Record 4 of Set 1 | punta arenas
# Processing Record 5 of Set 1 | rikitea
# Processing Record 6 of Set 1 | kayes
# Processing Record 7 of Set 1 | hobart
# Processing Record 8 of Set 1 | rawannawi
# City not found. Skipping...
# Processing Record 9 of Set 1 | parabel
# Processing Record 10 of Set 1 | esperance
# Processing Record 11 of Set 1 | ushuaia
# Processing Record 12 of Set 1 | maceio
# Processing Record 13 of Set 1 | byron bay
# Processing Record 14 of Set 1 | lebu
# Processing Record 15 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 16 of Set 1 | vaini
# Processing Record 17 of Set 1 | longlac
# City not found. Skipping...
# Processing Record 18 of Set 1 | vostok
# Processing Record 19 of Set 1 | artvin
# Processing Record 20 of Set 1 | chuy
# Processing Record 21 of Set 1 | norman wells
# Processing Record 22 of Set 1 | thompson
# Processing Record 23 of Set 1 | avarua
# Processing Record 24 of Set 1 | blagoyevo
# Processing Record 25 of Set 1 | ugoofaaru
# Processing Record 26 of Set 1 | albany
# Processing Record 27 of Set 1 | severo-kurilsk
# Processing Record 28 of Set 1 | mar del plata
# Processing Record 29 of Set 1 | nioro
# Processing Record 30 of Set 1 | hilo
# Processing Record 31 of Set 1 | sao filipe
# Processing Record 32 of Set 1 | solovetskiy
# City not found. Skipping...
# Processing Record 33 of Set 1 | lavrentiya
# Processing Record 34 of Set 1 | ilulissat
# Processing Record 35 of Set 1 | nanortalik
# Processing Record 36 of Set 1 | mount gambier
# Processing Record 37 of Set 1 | west bay
# Processing Record 38 of Set 1 | la tuque
# Processing Record 39 of Set 1 | qaanaaq
# Processing Record 40 of Set 1 | krasnoselkup
# Processing Record 41 of Set 1 | waingapu
# Processing Record 42 of Set 1 | gazion
# City not found. Skipping...
# Processing Record 43 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 44 of Set 1 | cape town
# Processing Record 45 of Set 1 | bethel
# Processing Record 46 of Set 1 | brae
# Processing Record 47 of Set 1 | ribeira grande
# Processing Record 48 of Set 1 | kapaa
# Processing Record 49 of Set 1 | saint anthony
# Processing Record 50 of Set 1 | lucea
# Processing Record 1 of Set 2 | upernavik
# Processing Record 2 of Set 2 | carutapera
# Processing Record 3 of Set 2 | busselton
# Processing Record 4 of Set 2 | yar-sale
# Processing Record 5 of Set 2 | mataura
# Processing Record 6 of Set 2 | provideniya
# Processing Record 7 of Set 2 | dong hoi
# Processing Record 8 of Set 2 | presidencia roque saenz pena
# Processing Record 9 of Set 2 | atuona
# Processing Record 10 of Set 2 | kavaratti
# Processing Record 11 of Set 2 | narsaq
# Processing Record 12 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 13 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 14 of Set 2 | esmeralda
# Processing Record 15 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 16 of Set 2 | leningradskiy
# Processing Record 17 of Set 2 | carnarvon
# Processing Record 18 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 19 of Set 2 | bushenyi
# Processing Record 20 of Set 2 | bhag
# Processing Record 21 of Set 2 | yeletskiy
# City not found. Skipping...
# Processing Record 22 of Set 2 | north myrtle beach
# Processing Record 23 of Set 2 | vila franca do campo
# Processing Record 24 of Set 2 | kamenskoye
# City not found. Skipping...
# Processing Record 25 of Set 2 | butaritari
# Processing Record 26 of Set 2 | clarksburg
# Processing Record 27 of Set 2 | arlit
# Processing Record 28 of Set 2 | sault sainte marie
# Processing Record 29 of Set 2 | barrow
# Processing Record 30 of Set 2 | atambua
# Processing Record 31 of Set 2 | madison
# Processing Record 32 of Set 2 | avera
# Processing Record 33 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 34 of Set 2 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 35 of Set 2 | puerto ayora
# Processing Record 36 of Set 2 | abu samrah
# Processing Record 37 of Set 2 | port elizabeth
# Processing Record 38 of Set 2 | touros
# Processing Record 39 of Set 2 | sembe
# Processing Record 40 of Set 2 | karaton
# Processing Record 41 of Set 2 | tuktoyaktuk
# Processing Record 42 of Set 2 | east london
# Processing Record 43 of Set 2 | vila
# Processing Record 44 of Set 2 | coihaique
# Processing Record 45 of Set 2 | rawson
# Processing Record 46 of Set 2 | tuatapere
# Processing Record 47 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 48 of Set 2 | alofi
# Processing Record 49 of Set 2 | bluff
# Processing Record 50 of Set 2 | aykhal
# Processing Record 1 of Set 3 | neiafu
# Processing Record 2 of Set 3 | betare oya
# Processing Record 3 of Set 3 | castro
# Processing Record 4 of Set 3 | fortuna
# Processing Record 5 of Set 3 | port alfred
# Processing Record 6 of Set 3 | bandarban
# Processing Record 7 of Set 3 | prainha
# Processing Record 8 of Set 3 | zhangye
# Processing Record 9 of Set 3 | atar
# Processing Record 10 of Set 3 | khiri mat
# Processing Record 11 of Set 3 | cerrito
# Processing Record 12 of Set 3 | lagoa
# Processing Record 13 of Set 3 | goderich
# Processing Record 14 of Set 3 | hami
# Processing Record 15 of Set 3 | haines junction
# Processing Record 16 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 17 of Set 3 | hay river
# Processing Record 18 of Set 3 | san cristobal
# Processing Record 19 of Set 3 | nikolskoye
# Processing Record 20 of Set 3 | souillac
# Processing Record 21 of Set 3 | gorban
# Processing Record 22 of Set 3 | namibe
# Processing Record 23 of Set 3 | kruisfontein
# Processing Record 24 of Set 3 | ambon
# Processing Record 25 of Set 3 | chilliwack
# Processing Record 26 of Set 3 | cherskiy
# Processing Record 27 of Set 3 | wahiawa
# Processing Record 28 of Set 3 | lompoc
# Processing Record 29 of Set 3 | olinda
# Processing Record 30 of Set 3 | grindavik
# Processing Record 31 of Set 3 | new norfolk
# Processing Record 32 of Set 3 | umba
# Processing Record 33 of Set 3 | arraial do cabo
# Processing Record 34 of Set 3 | hima
# Processing Record 35 of Set 3 | cidreira
# Processing Record 36 of Set 3 | khatanga
# Processing Record 37 of Set 3 | yellowknife
# Processing Record 38 of Set 3 | georgetown
# Processing Record 39 of Set 3 | pevek
# Processing Record 40 of Set 3 | tshikapa
# Processing Record 41 of Set 3 | pochutla
# Processing Record 42 of Set 3 | quang ngai
# Processing Record 43 of Set 3 | chillicothe
# Processing Record 44 of Set 3 | kodiak
# Processing Record 45 of Set 3 | porto walter
# Processing Record 46 of Set 3 | moose factory
# Processing Record 47 of Set 3 | tiksi
# Processing Record 48 of Set 3 | lorengau
# Processing Record 49 of Set 3 | nantucket
# Processing Record 50 of Set 3 | malumfashi
# Processing Record 1 of Set 4 | saskylakh
# Processing Record 2 of Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 3 of Set 4 | caravelas
# Processing Record 4 of Set 4 | camana
# Processing Record 5 of Set 4 | itoman
# Processing Record 6 of Set 4 | labuhan
# Processing Record 7 of Set 4 | vallenar
# Processing Record 8 of Set 4 | kaitangata
# Processing Record 9 of Set 4 | kuala lipis
# Processing Record 10 of Set 4 | bambous virieux
# Processing Record 11 of Set 4 | arcata
# Processing Record 12 of Set 4 | hermanus
# Processing Record 13 of Set 4 | nouadhibou
# Processing Record 14 of Set 4 | luang prabang
# Processing Record 15 of Set 4 | iquitos
# Processing Record 16 of Set 4 | dicabisagan
# Processing Record 17 of Set 4 | talnakh
# Processing Record 18 of Set 4 | le port
# Processing Record 19 of Set 4 | sibolga
# Processing Record 20 of Set 4 | necochea
# Processing Record 21 of Set 4 | sept-iles
# Processing Record 22 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 23 of Set 4 | utiroa
# City not found. Skipping...
# Processing Record 24 of Set 4 | campo verde
# Processing Record 25 of Set 4 | rungata
# City not found. Skipping...
# Processing Record 26 of Set 4 | progreso
# Processing Record 27 of Set 4 | mosquera
# Processing Record 28 of Set 4 | torbay
# Processing Record 29 of Set 4 | port lincoln
# Processing Record 30 of Set 4 | severomuysk
# Processing Record 31 of Set 4 | ramsey
# Processing Record 32 of Set 4 | berlevag
# Processing Record 33 of Set 4 | kahului
# Processing Record 34 of Set 4 | clyde river
# Processing Record 35 of Set 4 | bereda
# Processing Record 36 of Set 4 | paralimni
# Processing Record 37 of Set 4 | faanui
# Processing Record 38 of Set 4 | hithadhoo
# Processing Record 39 of Set 4 | lyubech
# Processing Record 40 of Set 4 | herat
# Processing Record 41 of Set 4 | smithers
# Processing Record 42 of Set 4 | bredasdorp
# Processing Record 43 of Set 4 | paragominas
# Processing Record 44 of Set 4 | miramar
# Processing Record 45 of Set 4 | broken hill
# Processing Record 46 of Set 4 | hambantota
# Processing Record 47 of Set 4 | igrim
# Processing Record 48 of Set 4 | ous
# Processing Record 49 of Set 4 | victoria
# Processing Record 50 of Set 4 | khandyga
# Processing Record 1 of Set 5 | vao
# Processing Record 2 of Set 5 | cabo san lucas
# Processing Record 3 of Set 5 | akyab
# Processing Record 4 of Set 5 | portland
# Processing Record 5 of Set 5 | jamestown
# Processing Record 6 of Set 5 | faya
# Processing Record 7 of Set 5 | guerrero negro
# Processing Record 8 of Set 5 | great yarmouth
# Processing Record 9 of Set 5 | laguna
# Processing Record 10 of Set 5 | bhigvan
# Processing Record 11 of Set 5 | narrabri
# Processing Record 12 of Set 5 | arequipa
# Processing Record 13 of Set 5 | saquena
# Processing Record 14 of Set 5 | san patricio
# Processing Record 15 of Set 5 | xichang
# Processing Record 16 of Set 5 | ruteng
# Processing Record 17 of Set 5 | margate
# Processing Record 18 of Set 5 | kimbe
# Processing Record 19 of Set 5 | uglegorsk
# Processing Record 20 of Set 5 | karratha
# Processing Record 21 of Set 5 | starovelichkovskaya
# Processing Record 22 of Set 5 | codrington
# Processing Record 23 of Set 5 | sao paulo de olivenca
# Processing Record 24 of Set 5 | walvis bay
# Processing Record 25 of Set 5 | general pico
# Processing Record 26 of Set 5 | poum
# Processing Record 27 of Set 5 | mezen
# Processing Record 28 of Set 5 | itaituba
# Processing Record 29 of Set 5 | karasjok
# Processing Record 30 of Set 5 | olafsvik
# Processing Record 31 of Set 5 | yulara
# Processing Record 32 of Set 5 | ambulu
# Processing Record 33 of Set 5 | mahon
# Processing Record 34 of Set 5 | gimli
# Processing Record 35 of Set 5 | pampas
# Processing Record 36 of Set 5 | ponta do sol
# Processing Record 37 of Set 5 | liverpool
# Processing Record 38 of Set 5 | kharp
# Processing Record 39 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 40 of Set 5 | puerto leguizamo
# Processing Record 41 of Set 5 | bengkulu
# Processing Record 42 of Set 5 | gallup
# Processing Record 43 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 44 of Set 5 | cherdyn
# Processing Record 45 of Set 5 | salalah
# Processing Record 46 of Set 5 | pangnirtung
# Processing Record 47 of Set 5 | bossembele
# City not found. Skipping...
# Processing Record 48 of Set 5 | port hardy
# Processing Record 49 of Set 5 | camacha
# Processing Record 50 of Set 5 | jiayuguan
# Processing Record 1 of Set 6 | kovdor
# Processing Record 2 of Set 6 | taburi
# City not found. Skipping...
# Processing Record 3 of Set 6 | sarangarh
# Processing Record 4 of Set 6 | bolshoy tsaryn
# City not found. Skipping...
# Processing Record 5 of Set 6 | chokurdakh
# Processing Record 6 of Set 6 | okhotsk
# Processing Record 7 of Set 6 | raga
# Processing Record 8 of Set 6 | hukuntsi
# Processing Record 9 of Set 6 | malakal
# Processing Record 10 of Set 6 | parit buntar
# Processing Record 11 of Set 6 | fort smith
# Processing Record 12 of Set 6 | gijon
# Processing Record 13 of Set 6 | iqaluit
# Processing Record 14 of Set 6 | mount isa
# Processing Record 15 of Set 6 | yumen
# Processing Record 16 of Set 6 | pisco
# Processing Record 17 of Set 6 | lastoursville
# Processing Record 18 of Set 6 | sangmelima
# Processing Record 19 of Set 6 | saint-augustin
# Processing Record 20 of Set 6 | poddorye
# Processing Record 21 of Set 6 | rio verde de mato grosso
# Processing Record 22 of Set 6 | ormara
# Processing Record 23 of Set 6 | la ronge
# Processing Record 24 of Set 6 | adrar
# Processing Record 25 of Set 6 | tasiilaq
# Processing Record 26 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 27 of Set 6 | hasaki
# Processing Record 28 of Set 6 | nome
# Processing Record 29 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 30 of Set 6 | bathsheba
# Processing Record 31 of Set 6 | uribia
# Processing Record 32 of Set 6 | lasa
# Processing Record 33 of Set 6 | banjarmasin
# Processing Record 34 of Set 6 | willowmore
# Processing Record 35 of Set 6 | bara
# Processing Record 36 of Set 6 | talawdi
# City not found. Skipping...
# Processing Record 37 of Set 6 | manzalesti
# City not found. Skipping...
# Processing Record 38 of Set 6 | lazaro cardenas
# Processing Record 39 of Set 6 | khorixas
# Processing Record 40 of Set 6 | aden
# Processing Record 41 of Set 6 | aksarka
# Processing Record 42 of Set 6 | fairbanks
# Processing Record 43 of Set 6 | manali
# Processing Record 44 of Set 6 | safaga
# Processing Record 45 of Set 6 | iskateley
# Processing Record 46 of Set 6 | kaspiysk
# Processing Record 47 of Set 6 | khorinsk
# Processing Record 48 of Set 6 | acarau
# Processing Record 49 of Set 6 | oxbow
# Processing Record 50 of Set 6 | port blair
# Processing Record 1 of Set 7 | sikasso
# Processing Record 2 of Set 7 | tura
# Processing Record 3 of Set 7 | bangassou
# Processing Record 4 of Set 7 | eureka
# Processing Record 5 of Set 7 | merrill
# Processing Record 6 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 7 of Set 7 | sangar
# Processing Record 8 of Set 7 | brumado
# Processing Record 9 of Set 7 | paciran
# Processing Record 10 of Set 7 | mahebourg
# Processing Record 11 of Set 7 | samarai
# Processing Record 12 of Set 7 | thinadhoo
# Processing Record 13 of Set 7 | oranjemund
# Processing Record 14 of Set 7 | saint-philippe
# Processing Record 15 of Set 7 | shibarghan
# City not found. Skipping...
# Processing Record 16 of Set 7 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 17 of Set 7 | mayo
# Processing Record 18 of Set 7 | toora-khem
# Processing Record 19 of Set 7 | vesyegonsk
# Processing Record 20 of Set 7 | nata
# Processing Record 21 of Set 7 | honningsvag
# Processing Record 22 of Set 7 | johnson city
# Processing Record 23 of Set 7 | sorvag
# City not found. Skipping...
# Processing Record 24 of Set 7 | piryion
# City not found. Skipping...
# Processing Record 25 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 26 of Set 7 | conde
# Processing Record 27 of Set 7 | ngukurr
# City not found. Skipping...
# Processing Record 28 of Set 7 | luderitz
# Processing Record 29 of Set 7 | erseke
# Processing Record 30 of Set 7 | beloha
# Processing Record 31 of Set 7 | tautira
# Processing Record 32 of Set 7 | bani walid
# Processing Record 33 of Set 7 | groningen
# Processing Record 34 of Set 7 | jalu
# Processing Record 35 of Set 7 | ingham
# Processing Record 36 of Set 7 | richards bay
# Processing Record 37 of Set 7 | anito
# Processing Record 38 of Set 7 | port macquarie
# Processing Record 39 of Set 7 | junagarh
# Processing Record 40 of Set 7 | miri
# Processing Record 41 of Set 7 | ahipara
# Processing Record 42 of Set 7 | chirongui
# Processing Record 43 of Set 7 | bafata
# Processing Record 44 of Set 7 | katherine
# Processing Record 45 of Set 7 | emerald
# Processing Record 46 of Set 7 | aripuana
# Processing Record 47 of Set 7 | arauca
# Processing Record 48 of Set 7 | isangel
# Processing Record 49 of Set 7 | hvammstangi
# City not found. Skipping...
# Processing Record 50 of Set 7 | bac lieu
# Processing Record 1 of Set 8 | wanning
# Processing Record 2 of Set 8 | zemio
# Processing Record 3 of Set 8 | oistins
# Processing Record 4 of Set 8 | lodja
# Processing Record 5 of Set 8 | mudyuga
# City not found. Skipping...
# Processing Record 6 of Set 8 | amalapuram
# Processing Record 7 of Set 8 | beihai
# Processing Record 8 of Set 8 | yeppoon
# Processing Record 9 of Set 8 | amapa
# Processing Record 10 of Set 8 | les cayes
# Processing Record 11 of Set 8 | maloshuyka
# City not found. Skipping...
# Processing Record 12 of Set 8 | litovko
# Processing Record 13 of Set 8 | lukh
# Processing Record 14 of Set 8 | rangapara
# Processing Record 15 of Set 8 | hwange
# Processing Record 16 of Set 8 | nieuw amsterdam
# Processing Record 17 of Set 8 | shimoda
# Processing Record 18 of Set 8 | pacific grove
# Processing Record 19 of Set 8 | warrnambool
# Processing Record 20 of Set 8 | gondanglegi
# Processing Record 21 of Set 8 | ilhabela
# Processing Record 22 of Set 8 | aloleng
# Processing Record 23 of Set 8 | zubova polyana
# Processing Record 24 of Set 8 | puerto escondido
# Processing Record 25 of Set 8 | viedma
# Processing Record 26 of Set 8 | nefteyugansk
# Processing Record 27 of Set 8 | yarega
# Processing Record 28 of Set 8 | cabedelo
# Processing Record 29 of Set 8 | lebanon
# Processing Record 30 of Set 8 | bagdarin
# Processing Record 31 of Set 8 | koumac
# Processing Record 32 of Set 8 | kovrov
# Processing Record 33 of Set 8 | stoyba
# City not found. Skipping...
# Processing Record 34 of Set 8 | saint george
# Processing Record 35 of Set 8 | ankazoabo
# Processing Record 36 of Set 8 | camopi
# Processing Record 37 of Set 8 | meyungs
# City not found. Skipping...
# Processing Record 38 of Set 8 | ahumada
# City not found. Skipping...
# Processing Record 39 of Set 8 | changji
# Processing Record 40 of Set 8 | maniitsoq
# Processing Record 41 of Set 8 | ostrovnoy
# Processing Record 42 of Set 8 | rio grande
# Processing Record 43 of Set 8 | gat
# Processing Record 44 of Set 8 | mineiros
# Processing Record 45 of Set 8 | kismayo
# Processing Record 46 of Set 8 | tual
# Processing Record 47 of Set 8 | nagua
# Processing Record 48 of Set 8 | vila velha
# Processing Record 49 of Set 8 | ixtapa
# Processing Record 50 of Set 8 | basco
# Processing Record 1 of Set 9 | tawkar
# City not found. Skipping...
# Processing Record 2 of Set 9 | warqla
# City not found. Skipping...
# Processing Record 3 of Set 9 | juifang
# City not found. Skipping...
# Processing Record 4 of Set 9 | kamenka
# Processing Record 5 of Set 9 | ozorkow
# Processing Record 6 of Set 9 | aklavik
# Processing Record 7 of Set 9 | ust-kuyga
# Processing Record 8 of Set 9 | san rafael
# Processing Record 9 of Set 9 | espinosa
# Processing Record 10 of Set 9 | bubaque
# Processing Record 11 of Set 9 | kavieng
# Processing Record 12 of Set 9 | kangaba
# Processing Record 13 of Set 9 | heihe
# Processing Record 14 of Set 9 | san vicente
# Processing Record 15 of Set 9 | padang
# Processing Record 16 of Set 9 | dudinka
# Processing Record 17 of Set 9 | harpalpur
# Processing Record 18 of Set 9 | christchurch
# Processing Record 19 of Set 9 | qingquan
# Processing Record 20 of Set 9 | mantua
# Processing Record 21 of Set 9 | najran
# Processing Record 22 of Set 9 | tir pol
# City not found. Skipping...
# Processing Record 23 of Set 9 | kutum
# Processing Record 24 of Set 9 | port keats
# Processing Record 25 of Set 9 | palauig
# Processing Record 26 of Set 9 | myrtle beach
# Processing Record 27 of Set 9 | beeville
# Processing Record 28 of Set 9 | chapais
# Processing Record 29 of Set 9 | road town
# Processing Record 30 of Set 9 | abalak
# Processing Record 31 of Set 9 | santo augusto
# Processing Record 32 of Set 9 | blackwater
# Processing Record 33 of Set 9 | samfya
# Processing Record 34 of Set 9 | dibulla
# Processing Record 35 of Set 9 | brownsville
# Processing Record 36 of Set 9 | hauterive
# Processing Record 37 of Set 9 | haibowan
# City not found. Skipping...
# Processing Record 38 of Set 9 | cayenne
# Processing Record 39 of Set 9 | rantauprapat
# Processing Record 40 of Set 9 | bur gabo
# City not found. Skipping...
# Processing Record 41 of Set 9 | noumea
# Processing Record 42 of Set 9 | capoterra
# Processing Record 43 of Set 9 | zambezi
# Processing Record 44 of Set 9 | kasongo-lunda
# Processing Record 45 of Set 9 | zomin
# Processing Record 46 of Set 9 | gladstone
# Processing Record 47 of Set 9 | saint-denis
# Processing Record 48 of Set 9 | whitehorse
# Processing Record 49 of Set 9 | serafimovich
# Processing Record 50 of Set 9 | imeni zhelyabova
# Processing Record 1 of Set 10 | rudnogorsk
# Processing Record 2 of Set 10 | fernie
# Processing Record 3 of Set 10 | henties bay
# Processing Record 4 of Set 10 | paamiut
# Processing Record 5 of Set 10 | derzhavinsk
# Processing Record 6 of Set 10 | poronaysk
# Processing Record 7 of Set 10 | bangolo
# Processing Record 8 of Set 10 | hobyo
# Processing Record 9 of Set 10 | muravlenko
# Processing Record 10 of Set 10 | naze
# Processing Record 11 of Set 10 | sabzevar
# Processing Record 12 of Set 10 | port augusta
# Processing Record 13 of Set 10 | sambava
# Processing Record 14 of Set 10 | samalaeulu
# City not found. Skipping...
# Processing Record 15 of Set 10 | gamba
# Processing Record 16 of Set 10 | itarema
# Processing Record 17 of Set 10 | bayir
# Processing Record 18 of Set 10 | inhambane
# Processing Record 19 of Set 10 | beyneu
# Processing Record 20 of Set 10 | ripky
# Processing Record 21 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 22 of Set 10 | anupgarh
# Processing Record 23 of Set 10 | srostki
# Processing Record 24 of Set 10 | jaque
# Processing Record 25 of Set 10 | abdulino
# Processing Record 26 of Set 10 | takoradi
# Processing Record 27 of Set 10 | ilanskiy
# Processing Record 28 of Set 10 | quatre cocos
# Processing Record 29 of Set 10 | valparaiso
# Processing Record 30 of Set 10 | burica
# City not found. Skipping...
# Processing Record 31 of Set 10 | katsuura
# Processing Record 32 of Set 10 | dunedin
# Processing Record 33 of Set 10 | buala
# Processing Record 34 of Set 10 | lehututu
# Processing Record 35 of Set 10 | ust-ilimsk
# Processing Record 36 of Set 10 | mahajanga
# Processing Record 37 of Set 10 | college
# Processing Record 38 of Set 10 | odweyne
# Processing Record 39 of Set 10 | plettenberg bay
# Processing Record 40 of Set 10 | mollendo
# Processing Record 41 of Set 10 | murud
# Processing Record 42 of Set 10 | talalayivka
# Processing Record 43 of Set 10 | swakopmund
# Processing Record 44 of Set 10 | palmer
# Processing Record 45 of Set 10 | novobureyskiy
# Processing Record 46 of Set 10 | gasa
# Processing Record 47 of Set 10 | salinopolis
# Processing Record 48 of Set 10 | perdoes
# Processing Record 49 of Set 10 | diamantino
# Processing Record 50 of Set 10 | kasiri
# Processing Record 1 of Set 11 | key largo
# Processing Record 2 of Set 11 | victoria point
# Processing Record 3 of Set 11 | amlame
# Processing Record 4 of Set 11 | sao joao da barra
# Processing Record 5 of Set 11 | hata
# Processing Record 6 of Set 11 | bonavista
# Processing Record 7 of Set 11 | roma
# Processing Record 8 of Set 11 | deputatskiy
# Processing Record 9 of Set 11 | okha
# Processing Record 10 of Set 11 | rosetta
# Processing Record 11 of Set 11 | magadan
# Processing Record 12 of Set 11 | novyy urgal
# Processing Record 13 of Set 11 | flinders
# Processing Record 14 of Set 11 | halifax
# Processing Record 15 of Set 11 | abbeville
# Processing Record 16 of Set 11 | abu dhabi
# Processing Record 17 of Set 11 | sorong
# Processing Record 18 of Set 11 | saldanha
# Processing Record 19 of Set 11 | santa rita
# Processing Record 20 of Set 11 | bouake
# Processing Record 21 of Set 11 | anloga
# Processing Record 22 of Set 11 | ketchikan
# Processing Record 23 of Set 11 | brigg
# Processing Record 24 of Set 11 | cockburn town
# Processing Record 25 of Set 11 | airai
# Processing Record 26 of Set 11 | srednekolymsk
# Processing Record 27 of Set 11 | kisaran
# Processing Record 28 of Set 11 | pouebo
# Processing Record 29 of Set 11 | grand gaube
# Processing Record 30 of Set 11 | puerto colombia
# Processing Record 31 of Set 11 | zhigansk
# Processing Record 32 of Set 11 | flin flon
# Processing Record 33 of Set 11 | los llanos de aridane
# Processing Record 34 of Set 11 | te anau
# Processing Record 35 of Set 11 | lakes entrance
# Processing Record 36 of Set 11 | puerto ayacucho
# Processing Record 37 of Set 11 | shieli
# Processing Record 38 of Set 11 | rio gallegos
# Processing Record 39 of Set 11 | strezhevoy
# Processing Record 40 of Set 11 | humaita
# Processing Record 41 of Set 11 | jiangkou
# Processing Record 42 of Set 11 | jinxi
# Processing Record 43 of Set 11 | macamic
# Processing Record 44 of Set 11 | mnogovershinnyy
# Processing Record 45 of Set 11 | iwaki
# Processing Record 46 of Set 11 | shache
# Processing Record 47 of Set 11 | wanlaweyn
# Processing Record 48 of Set 11 | vuktyl
# Processing Record 49 of Set 11 | quelimane
# Processing Record 50 of Set 11 | watertown
# Processing Record 1 of Set 12 | puerto montt
# Processing Record 2 of Set 12 | nouakchott
# Processing Record 3 of Set 12 | wundanyi
# Processing Record 4 of Set 12 | maragogi
# Processing Record 5 of Set 12 | papetoai
# Processing Record 6 of Set 12 | raiganj
# Processing Record 7 of Set 12 | klaksvik
# Processing Record 8 of Set 12 | prince rupert
# Processing Record 9 of Set 12 | fare
# Processing Record 10 of Set 12 | kerema
# Processing Record 11 of Set 12 | sulangan
# Processing Record 12 of Set 12 | kishi
# Processing Record 13 of Set 12 | ponta delgada
# Processing Record 14 of Set 12 | meridian
# Processing Record 15 of Set 12 | opuwo
# Processing Record 16 of Set 12 | biak
# Processing Record 17 of Set 12 | xam nua
# Processing Record 18 of Set 12 | gushikawa
# Processing Record 19 of Set 12 | comodoro rivadavia
# Processing Record 20 of Set 12 | garachine
# Processing Record 21 of Set 12 | tazovskiy
# Processing Record 22 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 23 of Set 12 | wilmington
# Processing Record 24 of Set 12 | soe
# Processing Record 25 of Set 12 | caconda
# Processing Record 26 of Set 12 | healdsburg
# Processing Record 27 of Set 12 | dondo
# Processing Record 28 of Set 12 | abashiri
# Processing Record 29 of Set 12 | conceicao da barra
# Processing Record 30 of Set 12 | moctezuma
# Processing Record 31 of Set 12 | saint-georges
# Processing Record 32 of Set 12 | carmen
# Processing Record 33 of Set 12 | mizdah
# Processing Record 34 of Set 12 | ardatov
# Processing Record 35 of Set 12 | cuamba
# Processing Record 36 of Set 12 | garwa
# Processing Record 37 of Set 12 | constitucion
# Processing Record 38 of Set 12 | bentong
# Processing Record 39 of Set 12 | collie
# Processing Record 40 of Set 12 | bilma
# Processing Record 41 of Set 12 | meadville
# Processing Record 42 of Set 12 | kununurra
# Processing Record 43 of Set 12 | waitati
# Processing Record 44 of Set 12 | lakhdenpokhya
# Processing Record 45 of Set 12 | antofagasta
# Processing Record 46 of Set 12 | kota bahru
# Processing Record 47 of Set 12 | sovetskiy
# Processing Record 48 of Set 12 | huron
# Processing Record 49 of Set 12 | radford
# Processing Record 50 of Set 12 | ambunti
# Processing Record 1 of Set 13 | umtata
# Processing Record 2 of Set 13 | hihifo
# City not found. Skipping...
# Processing Record 3 of Set 13 | verkhnevilyuysk
# Processing Record 4 of Set 13 | poya
# Processing Record 5 of Set 13 | bressuire
# Processing Record 6 of Set 13 | artyk
# City not found. Skipping...
# Processing Record 7 of Set 13 | khargone
# Processing Record 8 of Set 13 | skegness
# Processing Record 9 of Set 13 | folldal
# Processing Record 10 of Set 13 | belmonte
# Processing Record 11 of Set 13 | salinas
# Processing Record 12 of Set 13 | nuuk
# Processing Record 13 of Set 13 | iquique
# Processing Record 14 of Set 13 | pitimbu
# Processing Record 15 of Set 13 | bacuit
# City not found. Skipping...
# Processing Record 16 of Set 13 | wajima
# Processing Record 17 of Set 13 | windham
# Processing Record 18 of Set 13 | tomatlan
# Processing Record 19 of Set 13 | south lake tahoe
# Processing Record 20 of Set 13 | yenagoa
# Processing Record 21 of Set 13 | sisimiut
# Processing Record 22 of Set 13 | erenhot
# Processing Record 23 of Set 13 | suffolk
# Processing Record 24 of Set 13 | durant
# Processing Record 25 of Set 13 | nelson bay
# Processing Record 26 of Set 13 | mullaitivu
# City not found. Skipping...
# Processing Record 27 of Set 13 | katangli
# Processing Record 28 of Set 13 | huaiyin
# Processing Record 29 of Set 13 | hamilton
# Processing Record 30 of Set 13 | verkhnyaya inta
# Processing Record 31 of Set 13 | shaunavon
# Processing Record 32 of Set 13 | talakan
# Processing Record 33 of Set 13 | talas
# Processing Record 34 of Set 13 | puerto suarez
# Processing Record 35 of Set 13 | victor harbor
# Processing Record 36 of Set 13 | svetlaya
# Processing Record 37 of Set 13 | huicheng
# Processing Record 38 of Set 13 | leirvik
# Processing Record 39 of Set 13 | alotau
# City not found. Skipping...
# Processing Record 40 of Set 13 | itupiranga
# Processing Record 41 of Set 13 | wattegama
# Processing Record 42 of Set 13 | chhukha
# City not found. Skipping...
# Processing Record 43 of Set 13 | sinnamary
# Processing Record 44 of Set 13 | maghama
# City not found. Skipping...
# Processing Record 45 of Set 13 | ukiah
# Processing Record 46 of Set 13 | harper
# Processing Record 47 of Set 13 | porto novo
# Processing Record 48 of Set 13 | sakakah
# Processing Record 49 of Set 13 | cikupa
# Processing Record 50 of Set 13 | taoudenni
# Processing Record 1 of Set 14 | warin chamrap
# Processing Record 2 of Set 14 | sur
# Processing Record 3 of Set 14 | umm lajj
# Processing Record 4 of Set 14 | lomza
# Processing Record 5 of Set 14 | follonica
# Processing Record 6 of Set 14 | inuvik
# Processing Record 7 of Set 14 | geraldton
# Processing Record 8 of Set 14 | turbat
# Processing Record 9 of Set 14 | araceli
# Processing Record 10 of Set 14 | alice springs
# Processing Record 11 of Set 14 | north bend
# Processing Record 12 of Set 14 | vilhena
# Processing Record 13 of Set 14 | kerki
# City not found. Skipping...
# Processing Record 14 of Set 14 | dawlatabad
# Processing Record 15 of Set 14 | wolmaranstad
# City not found. Skipping...
# Processing Record 16 of Set 14 | wardha
# Processing Record 17 of Set 14 | izhma
# Processing Record 18 of Set 14 | marzuq
# Processing Record 19 of Set 14 | lake charles
# Processing Record 20 of Set 14 | pospelikha
# Processing Record 21 of Set 14 | abu jubayhah
# City not found. Skipping...
# Processing Record 22 of Set 14 | calabozo
# Processing Record 23 of Set 14 | hereford
# Processing Record 24 of Set 14 | kyabram
# Processing Record 25 of Set 14 | asfi
# Processing Record 26 of Set 14 | bambanglipuro
# Processing Record 27 of Set 14 | saint-francois
# Processing Record 28 of Set 14 | hoquiam
# Processing Record 29 of Set 14 | riyadh
# Processing Record 30 of Set 14 | bako
# Processing Record 31 of Set 14 | nabire
# Processing Record 32 of Set 14 | sataua
# City not found. Skipping...
# Processing Record 33 of Set 14 | hailun
# Processing Record 34 of Set 14 | isiro
# Processing Record 35 of Set 14 | sitka
# Processing Record 36 of Set 14 | terney
# Processing Record 37 of Set 14 | bandarbeyla
# Processing Record 38 of Set 14 | chekalin
# Processing Record 39 of Set 14 | kisangani
# Processing Record 40 of Set 14 | guane
# Processing Record 41 of Set 14 | sorland
# Processing Record 42 of Set 14 | santa cruz
# Processing Record 43 of Set 14 | kibala
# Processing Record 44 of Set 14 | anadyr
# Processing Record 45 of Set 14 | qui nhon
# Processing Record 46 of Set 14 | taksimo
# Processing Record 47 of Set 14 | olavarria
# Processing Record 48 of Set 14 | mys shmidta
# City not found. Skipping...
# Processing Record 49 of Set 14 | muli
# Processing Record 50 of Set 14 | husavik
# Processing Record 1 of Set 15 | vagur
# Processing Record 2 of Set 15 | london
# Processing Record 3 of Set 15 | macaboboni
# City not found. Skipping...
# Processing Record 4 of Set 15 | egvekinot
# Processing Record 5 of Set 15 | kyzyl-suu
# Processing Record 6 of Set 15 | ust-kut
# Processing Record 7 of Set 15 | port-gentil
# Processing Record 8 of Set 15 | matamoros
# Processing Record 9 of Set 15 | tevriz
# Processing Record 10 of Set 15 | hualmay
# Processing Record 11 of Set 15 | puerto penasco
# Processing Record 12 of Set 15 | sao jose da coroa grande
# Processing Record 13 of Set 15 | mecca
# Processing Record 14 of Set 15 | namatanai
# Processing Record 15 of Set 15 | nemuro
# Processing Record 16 of Set 15 | mitu
# Processing Record 17 of Set 15 | lugo
# Processing Record 18 of Set 15 | wulanhaote
# City not found. Skipping...
# Processing Record 19 of Set 15 | umred
# Processing Record 20 of Set 15 | kita
# Processing Record 21 of Set 15 | altay
# Processing Record 22 of Set 15 | harrisonville
# Processing Record 23 of Set 15 | pierre
# Processing Record 24 of Set 15 | novokizhinginsk
# Processing Record 25 of Set 15 | whittlesea
# Processing Record 26 of Set 15 | yuzhno-kurilsk
# Processing Record 27 of Set 15 | teya
# Processing Record 28 of Set 15 | dwarka
# Processing Record 29 of Set 15 | northam
# Processing Record 30 of Set 15 | pinotepa nacional
# Processing Record 31 of Set 15 | bolshaya irba
# City not found. Skipping...
# Processing Record 32 of Set 15 | pafos
# Processing Record 33 of Set 15 | kijang
# Processing Record 34 of Set 15 | seoul
# Processing Record 35 of Set 15 | birin
# Processing Record 36 of Set 15 | olden
# Processing Record 37 of Set 15 | beringovskiy
# Processing Record 38 of Set 15 | mirabad
# Processing Record 39 of Set 15 | montepuez
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 671

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Coahuayana  18.7333 -103.6833     76.93        82           0
# 1        Dikson  73.5069   80.5464     -9.90       100          96
# 2  Punta Arenas -53.1500  -70.9167     51.91        62           0
# 3       Rikitea -23.1203 -134.9692     74.17        87          81
# 4         Kayes  14.0000  -11.0000     79.23        16           6
# 5        Hobart -42.8794  147.3294     56.26        72          75
# 6       Parabel  58.6978   81.4825     32.20        98         100
# 7     Esperance -33.8667  121.9000     57.04        70          96
# 8       Ushuaia -54.8000  -68.3000     55.06        44           0
# 9        Maceio  -9.6658  -35.7353     76.77        88          16
#
#    Wind Speed Country
# 0        3.71      MX
# 1        5.57      RU
# 2       17.27      CL
# 3       18.14      PF
# 4        2.95      ML
# 5        2.30      AU
# 6        6.35      RU
# 7       19.73      AU
# 8        9.22      AR
# 9        7.40      BR

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]
# Display sample data
city_data_df.head()
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Coahuayana      MX  18.7333 -103.6833     76.93        82           0
# 1        Dikson      RU  73.5069   80.5464     -9.90       100          96
# 2  Punta Arenas      CL -53.1500  -70.9167     51.91        62           0
# 3       Rikitea      PF -23.1203 -134.9692     74.17        87          81
# 4         Kayes      ML  14.0000  -11.0000     79.23        16           6
#
#    Wind Speed
# 0        3.71
# 1        5.57
# 2       17.27
# 3       18.14
# 4        2.95

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City           object
# Country        object
# Lat           float64
# Lng           float64
# Max Temp      float64
# Humidity        int64
# Cloudiness      int64
# Wind Speed    float64
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="Citi_ID")
